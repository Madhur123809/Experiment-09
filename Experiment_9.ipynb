# %% [markdown]
# Experiment No.9
#
# Aim : Study of Numpy Library
#
# Madhur Gupta
#
# 25070123070

# %%
#why Numpy?
#faster than lists
# used for numerical compututational
# base for pandas

# %%
# data should be in matrix fpr numpy

# %%
#Declaration of Numpy
import numpy as np

a = np.array([1,10,20,30,40,50,500])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [  1  10  20  30  40  50 500]
# [[1 2 3]
#  [4 5 6]]

# %%
#Dimension of Array(it is used to know whether it is 1 d ,2 d )
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
#size of matrix
print(a.size)
print(b.size)
# Out:
# 7
# 6

# %%
print(a.shape)
print(b.shape)
# Out:
# (7,)
# (2, 3)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
# In built function using Numpy
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3) ,dtype=int)
# Out:
# array([[1, 1, 1],
#        [1, 1, 1]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,11,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,4)
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
print(b * 2)
print(b + 2)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
# [[3 4 5]
#  [6 7 8]]

# %%
print(np.mean(a))
# Out:
# 93.0

# %%
print(np.sum(a))
# Out:
# 651
